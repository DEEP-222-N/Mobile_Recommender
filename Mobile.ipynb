# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import NearestNeighbors
import pickle

# %%
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/Projects/ML/cleaned_mobile_dataset.csv")

# %%
df.head()
# Out:
#   Company Name      Model Name   Processor  Screen Size (inches)  \
# 0        Apple       iPhone 16  A17 Bionic                   6.1
# 1        Apple       iPhone 16  A17 Bionic                   6.1
# 2        Apple       iPhone 16  A17 Bionic                   6.1
# 3        Apple  iPhone 16 Plus  A17 Bionic                   6.7
# 4        Apple  iPhone 16 Plus  A17 Bionic                   6.7
#
#    Launched Price (INR)  Launched Price (CNY)  Launched Price (USD)  \
# 0               79999.0                5799.0                 799.0
# 1               84999.0                6099.0                 849.0
# 2               89999.0                6499.0                 899.0
# 3               89999.0                6199.0                 899.0
# 4               94999.0                6499.0                 949.0
#
#    Launched Price (AED)  Launched Year  Storage_GB  ...  Front Cam Total MP  \
# 0                2799.0           2024       128.0  ...                  12
# ...

# %%
features = ['Launched Price (INR)', 'RAM_GB', 'Storage_GB', 'Battery Capacity(mAh)','Back Cam Primary (MP)', 'Front Cam Primary (MP)']

# %%
df_filtered = df.dropna(subset=features)

# %%
df_filtered.isna().sum()
# Out:
# Company Name              0
# Model Name                0
# Processor                 0
# Screen Size (inches)      0
# Launched Price (INR)      0
# Launched Price (CNY)      0
# Launched Price (USD)      0
# Launched Price (AED)      0
# Launched Year             0
# Storage_GB                0
# RAM_GB                    0
# Back Cam Primary (MP)     0
# Back Cam Total MP         0
# Back Num of Cams          0
# Front Cam Primary (MP)    0
# Front Cam Total MP        0
# Front Num of Cams         0
# Mobile Weight(g)          0
# CNY to INR                0
# USD to INR                0
# AED to INR                0
# Diff INR vs CNY-INR       0
# Diff INR vs USD-INR       0
# Diff INR vs AED-INR       0
# Battery Capacity(mAh)     0
# dtype: int64

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df_filtered[features])

# %%
knn = NearestNeighbors(n_neighbors=3, metric='euclidean')
knn.fit(X_scaled)
# Out:
# NearestNeighbors(metric='euclidean', n_neighbors=3)

# %%
# Save model and data
with open("knn_model.pkl", "wb") as f:
    pickle.dump((knn, scaler, df_filtered), f)
